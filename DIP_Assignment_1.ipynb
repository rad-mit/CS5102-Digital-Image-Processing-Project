# %% [markdown]
# # Libraries

# %%
from matplotlib import pyplot as plt                                              
import cv2
import glob
import os
import numpy as np
import ntpath
import math

# %% [markdown]
# # Setup and Intialisation

# %%
cwd = os.getcwd() # get current directory
input_image_dir_list=glob.glob(cwd+"/Input-Images/*.jpg") #  image (.jpg) file path list in input folder
print(input_image_dir_list[1])
# Out:
# g:\My Drive\IIITDM\Research_Scholar\Course-Digital-Image-Processing\CS5102-Digital-Image-Processing-Assignment-1/Input-Images\20220114_082125.jpg

# %% [markdown]
# # Read images and store it in list

# %%
## Assuming input image shape is same.
input_image_data_list=[]
for f in sorted(input_image_dir_list):

        img = cv2.imread(f)  
        im2arr = np.asarray(img)
        input_image_data_list.append(im2arr)
        #print(im2arr.shape)

input_image_data_list=np.array(input_image_data_list)        
print(input_image_data_list.shape)
# Out:
# (50, 3264, 2448, 3)

# %% [markdown]
# # Display images

# %%
f = plt.figure()
f.set_figwidth(6*3)
f.set_figheight(4*3)

for i in range(10):
    # display Different Angle
    ax = plt.subplot(5, 10, i+1)
    plt.imshow(input_image_data_list[i,:, :, ::-1])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display Different Distance
    ax = plt.subplot(5, 10, i +1+ 10)
    plt.imshow(input_image_data_list[i+10,:, :, ::-1])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    # display Different Illumination
    ax = plt.subplot(5, 10, i +1+ 10 + 10)
    plt.imshow(input_image_data_list[i+10+10,:, :, ::-1])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display Different Expressions
    ax = plt.subplot(5, 10, i +1+ 10 + 10 + 10)
    plt.imshow(input_image_data_list[i+10+10+10,:, :, ::-1])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display Different Styles
    ax = plt.subplot(5, 10, i +1+ 10 + 10 + 10+10)
    plt.imshow(input_image_data_list[i+10+10+10+10,:, :, ::-1])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.figtext(0.5,0.9, "Different Angle", ha="center", va="top", fontsize=14, color="r")
plt.figtext(0.5,0.75, "Different Distance", ha="center", va="top", fontsize=14, color="r")
plt.figtext(0.5,0.6, "Different Illumination", ha="center", va="top", fontsize=14, color="r")
plt.figtext(0.5,0.42, "Different Expressions", ha="center", va="top", fontsize=14, color="r")
plt.figtext(0.5,0.25, "Different Styles", ha="center", va="top", fontsize=14, color="r")
plt.subplots_adjust(hspace = 0.5 )
plt.show()

# %%
reference_image=input_image_data_list[0]

# %%
color_image_rmse=[]
for i in range(len(input_image_data_list)-1):
    i=i+1
    rmse=math.sqrt(np.mean(np.square(reference_image-input_image_data_list[i])))
    color_image_rmse.append(rmse)  
color_image_rmse=np.array(color_image_rmse)      
print(color_image_rmse.shape)
# Out:
# (49,)

# %%
#error=input_image_data_list[0]-input_image_data_list[6]
#error_square=np.square(error)
#error_square_mean=np.mean(error_square)
#error_square_mean_root=math.sqrt(error_square_mean)

# %%
#print(error_square_mean_root)

# %% [markdown]
# # Plot "Image number vs RMSE score" (Color)

# %%
#  Plot the values in the graph with the indexed images in the X-axis and RMSE score in the Y-axis.
plt.title("Image number vs RMSE score", fontsize=20)
plt.xlabel("Image number")
plt.ylabel("RMSE score")
plt.plot(color_image_rmse)
plt.show()

# %% [markdown]
# # Convert the color images to grayscale images

# %%
gray_image_data_list=[]
for i in input_image_data_list:
    gray = cv2.cvtColor(i, cv2.COLOR_BGR2GRAY)
    gray_image_data_list.append(gray)
gray_image_data_list=np.array(gray_image_data_list)      
print(gray_image_data_list.shape)
# Out:
# (50, 3264, 2448)

# %% [markdown]
# # Display Grayscale images

# %%
f = plt.figure()
f.set_figwidth(6*3)
f.set_figheight(4*3)

for i in range(10):

    ax = plt.subplot(5, 10, i+1)
    plt.imshow(gray_image_data_list[i,:, :], cmap='gray', vmin = 0, vmax = 255)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)


    ax = plt.subplot(5, 10, i +1+ 10)
    plt.imshow(gray_image_data_list[i+10,:, :], cmap='gray', vmin = 0, vmax = 255)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    

    ax = plt.subplot(5, 10, i +1+ 10 + 10)
    plt.imshow(gray_image_data_list[i+20,:, :], cmap='gray', vmin = 0, vmax = 255)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)


    ax = plt.subplot(5, 10, i +1+ 10 + 10 + 10)
    plt.imshow(gray_image_data_list[i+30,:, :], cmap='gray', vmin = 0, vmax = 255)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)


    ax = plt.subplot(5, 10, i +1+ 10 + 10 + 10+10)
    plt.imshow(gray_image_data_list[i+40,:, :], cmap='gray', vmin = 0, vmax = 255)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.figtext(0.5,0.9, "Different Angle", ha="center", va="top", fontsize=14, color="r")
plt.figtext(0.5,0.75, "Different Distance", ha="center", va="top", fontsize=14, color="r")
plt.figtext(0.5,0.6, "Different Illumination", ha="center", va="top", fontsize=14, color="r")
plt.figtext(0.5,0.42, "Different Expressions", ha="center", va="top", fontsize=14, color="r")
plt.figtext(0.5,0.25, "Different Styles", ha="center", va="top", fontsize=14, color="r")
plt.subplots_adjust(hspace = 0.5 )
plt.show()

# %% [markdown]
# # RMSE (Gray)

# %%
reference_gray_image=gray_image_data_list[0]
gray_image_rmse=[]
for i in range(len(gray_image_data_list)-1):
    i=i+1
    rmse=math.sqrt(np.mean(np.square(reference_gray_image-gray_image_data_list[i])))
    gray_image_rmse.append(rmse)  
gray_image_rmse=np.array(gray_image_rmse)      
print(gray_image_rmse.shape)
# Out:
# (49,)

# %% [markdown]
# # Plot "Image number vs RMSE score" (Grayscale)

# %%
plt.title("Image number vs RMSE score", fontsize=20)
plt.xlabel("Image number")
plt.ylabel("RMSE score")
plt.plot(gray_image_rmse)
plt.show()
